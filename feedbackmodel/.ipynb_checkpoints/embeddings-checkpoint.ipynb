# %%
# !pip install -U sentence-transformers
# Out:
# ...
#   Using cached sentence_transformers-5.2.0-py3-none-any.whl.metadata (16 kB)
# ...
# Using cached sentence_transformers-5.2.0-py3-none-any.whl (493 kB)
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformers, util
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sentence_transformers import SentenceTransformers, util
#
# ModuleNotFoundError: No module named 'sentence_transformers'
